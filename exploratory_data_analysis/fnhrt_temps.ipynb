# %%
import os
import pandas as pd
import numpy as np
from dotenv import load_dotenv
from google.cloud import bigquery
pd.set_option('display.max_rows', 100)    # Show all rows



load_dotenv()
query_path = os.environ.get('BASE_QUERY_PATH')
client = bigquery.Client(os.environ.get('BIGQUERY_PROJECT_NAME'))

# %%
print(os.environ.get('BIGQUERY_PROJECT_NAME'))
# Out:
# phys-439706

# %%
# get the types of items that can be administered to a patient

with open(f"{query_path}/FNHTR/all_temps_ids.sql", 'r') as file:
    temps_reads = file.read()

temp_result = client.query(temps_reads).to_dataframe()
temp_result
# Out:
# /home/tyx1999120755/.pyenv/versions/3.12.7/envs/transfusion/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    itemid       temperature_label  unique_patients  total_measurements  \
# 0  223761  Temperature Fahrenheit            17498              522143
# 1  223762     Temperature Celsius             2181               74144
#
#    avg_temperature  min_temperature  max_temperature
# 0         98.40797            -99.9           9637.0
# 1         37.32990             -3.0            376.5

# %%
# get the types of items that can be administered to a patient

with open(f"{query_path}/FNHTR/temps_overlap.sql", 'r') as file:
    overlap_detection = file.read()

overlap_detection_result = client.query(overlap_detection).to_dataframe()
overlap_detection_result
# Out:
# /home/tyx1999120755/.pyenv/versions/3.12.7/envs/transfusion/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    unique_patients_a  unique_patients_b  overlapping_subjects
# 0              17498               2181                  2058

# %%
# get the types of items that can be administered to a patient

with open(f"{query_path}/fnhrt_temps.sql", 'r') as file:
    FNHRT_read = file.read()

FNHRT_result = client.query(FNHRT_read).to_dataframe()
FNHRT_result
# Out:
# /home/tyx1999120755/.pyenv/versions/3.12.7/envs/transfusion/lib/python3.12/site-packages/google/cloud/bigquery/table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#        subject_id  hadm_id  icustay_id transfusion_starttime  \
# 0             109   126055      236124   2141-10-17 17:45:00
# 1             109   158943      243532   2142-03-21 10:45:00
# 2             109   102024      232807   2142-06-01 21:00:00
# 3             124   138376      256064   2166-01-11 04:53:00
# 4             124   138376      256064   2166-01-11 04:53:00
# ...           ...      ...         ...                   ...
# 17383       99939   159023      252442   2110-03-22 07:15:00
# 17384       99939   159023      252442   2110-03-22 07:15:00
# 17385       99939   159023      252442   2110-03-22 07:15:00
# 17386       99939   159023      252442   2110-03-22 07:15:00
# 17387       99939   159023      252442   2110-03-22 07:15:00
#
#        temp_recorded_time  temperature_fahrenheit  baseline_temp_f  \
# 0     2141-10-24 05:00:00                   100.8             98.7
# 1     2142-03-21 22:43:00                   100.5              NaN
# 2     2142-06-01 23:00:00                   100.8              NaN
# 3     2166-01-25 20:00:00                    99.9             98.1
# 4     2166-01-22 08:00:00                   100.8             98.1
# ...                   ...                     ...              ...
# 17383 2110-03-23 10:00:00                    99.4             96.4
# 17384 2110-03-23 09:00:00                    99.8             96.4
# 17385 2110-03-22 21:00:00                    99.2             96.4
# 17386 2110-03-23 15:00:00                    99.3             96.4
# 17387 2110-03-23 12:00:00                    99.3             96.4
#
#                                      fnthr_criteria
# 0                       Temperature ≥38°C (100.4°F)
# 1                       Temperature ≥38°C (100.4°F)
# 2                       Temperature ≥38°C (100.4°F)
# 3      Temperature rise ≥1°C (1.8°F) above baseline
# 4                       Temperature ≥38°C (100.4°F)
# ...                                             ...
# 17383  Temperature rise ≥1°C (1.8°F) above baseline
# 17384  Temperature rise ≥1°C (1.8°F) above baseline
# 17385  Temperature rise ≥1°C (1.8°F) above baseline
# 17386  Temperature rise ≥1°C (1.8°F) above baseline
# 17387  Temperature rise ≥1°C (1.8°F) above baseline
#
# [17388 rows x 8 columns]

# %%
#Check unique patients
unique_patients = FNHRT_result.drop_duplicates(subset=['subject_id']).reset_index(drop=True)
len(unique_patients)
# Out:
# 1600
